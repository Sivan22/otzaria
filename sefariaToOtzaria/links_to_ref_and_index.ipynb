# %%
import pandas as pd
import glob

# %%
refs = pd.read_csv('..\\..\\refs\\refs.csv')
links = pd.DataFrame()

# %%
csv_files = glob.glob('../../Sefaria-Export/links/links*.csv')
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    links = pd.concat([links, df])

# %%
refs
# Out:
#                                     ref                   heRef  \
# 0        Chayei Moharan, Introduction 1  חיי מוהר"ן, הקדמה,  א,
# 1        Chayei Moharan, Introduction 2  חיי מוהר"ן, הקדמה,  ב,
# 2        Chayei Moharan, Introduction 3  חיי מוהר"ן, הקדמה,  ג,
# 3        Chayei Moharan, Introduction 4  חיי מוהר"ן, הקדמה,  ד,
# 4        Chayei Moharan, Introduction 5  חיי מוהר"ן, הקדמה,  ה,
# ...                                 ...                     ...
# 2970663           Tosefta Terumot 10:14    תוספתא תרומות י, יד,
# 2970664           Tosefta Terumot 10:15    תוספתא תרומות י, טו,
# 2970665           Tosefta Terumot 10:16    תוספתא תרומות י, טז,
# 2970666           Tosefta Terumot 10:17    תוספתא תרומות י, יז,
# 2970667           Tosefta Terumot 10:18    תוספתא תרומות י, יח,
#
#                                                      path  line_index
# 0                           אוצריא\חסידות\ברסלב\חיי מוהרן           4
# 1                           אוצריא\חסידות\ברסלב\חיי מוהרן           5
# 2                           אוצריא\חסידות\ברסלב\חיי מוהרן           6
# 3                           אוצריא\חסידות\ברסלב\חיי מוהרן           7
# 4                           אוצריא\חסידות\ברסלב\חיי מוהרן           8
# ...                                                   ...         ...
# 2970663  אוצריא\תוספתא\דפוס וילנא\סדר זרעים\תוספתא תרומות         175
# 2970664  אוצריא\תוספתא\דפוס וילנא\סדר זרעים\תוספתא תרומות         176
# 2970665  אוצריא\תוספתא\דפוס וילנא\סדר זרעים\תוספתא תרומות         177
# 2970666  אוצריא\תוספתא\דפוס וילנא\סדר זרעים\תוספתא תרומות         178
# 2970667  אוצריא\תוספתא\דפוס וילנא\סדר זרעים\תוספתא תרומות         179
#
# [2970668 rows x 4 columns]

# %%
links
# Out:
#                                               Citation 1        Citation 2  \
# 0      A Jewish Critique of the Philosophy of Martin ...      Berakhot 63b
# 1      A Jewish Critique of the Philosophy of Martin ...       Shabbat 88b
# 2       A New Israeli Commentary on Pirkei Avot 1:10:1-6  Pirkei Avot 1:10
# 3        A New Israeli Commentary on Pirkei Avot 1:10:13      Sanhedrin 4a
# 4         A New Israeli Commentary on Pirkei Avot 1:10:8    Pesachim 70b:5
# ...                                                  ...               ...
# 75643                                                NaN               NaN
# 75644                                                NaN               NaN
# 75645                                                NaN               NaN
# 75646                                                NaN               NaN
# 75647                                                NaN               NaN
#
#       Conection Type                                             Text 1  \
# 0                NaN  A Jewish Critique of the Philosophy of Martin ...
# 1                NaN  A Jewish Critique of the Philosophy of Martin ...
# 2         commentary            A New Israeli Commentary on Pirkei Avot
# 3                NaN            A New Israeli Commentary on Pirkei Avot
# 4                NaN            A New Israeli Commentary on Pirkei Avot
# ...              ...                                                ...
# 75643            NaN                                               Yoma
# 75644            NaN                                    Zakhor VeShamor
# 75645            NaN                                          Zechariah
# 75646            NaN                                          Zechariah
# 75647            NaN                                          Zephaniah
#
#                                  Text 2      Category 1 Category 2  Link Count
# 0                              Berakhot  Jewish Thought     Talmud         NaN
# 1                               Shabbat  Jewish Thought     Talmud         NaN
# 2                           Pirkei Avot         Mishnah    Mishnah         NaN
# 3                             Sanhedrin         Mishnah     Talmud         NaN
# 4                              Pesachim         Mishnah     Talmud         NaN
# ...                                 ...             ...        ...         ...
# 75643  Zevach Pesach on Pesach Haggadah             NaN        NaN         1.0
# 75644                         Zephaniah             NaN        NaN         1.0
# 75645                         Zechariah             NaN        NaN         1.0
# 75646                          Zevachim             NaN        NaN         1.0
# 75647                     Zohar Chadash             NaN        NaN         1.0
#
# [3505317 rows x 8 columns]

# %%
merged_df_citation1 = links.merge(refs, left_on='Citation 1', right_on='ref', how='left')

# %%
merged_df_citation1['path'].unique().__len__()
# Out:
# 4224

# %%
merged_df_citation1 = links.merge(refs, left_on='Citation 1', right_on='ref', how='left')
merged_df = merged_df_citation1.merge(refs, left_on='Citation 2', right_on='ref', how='left', suffixes=('_1', '_2'))

# %%
merged_df.head()
# Out:
#                                           Citation 1        Citation 2  \
# 0  A Jewish Critique of the Philosophy of Martin ...      Berakhot 63b
# 1  A Jewish Critique of the Philosophy of Martin ...       Shabbat 88b
# 2   A New Israeli Commentary on Pirkei Avot 1:10:1-6  Pirkei Avot 1:10
# 3    A New Israeli Commentary on Pirkei Avot 1:10:13      Sanhedrin 4a
# 4     A New Israeli Commentary on Pirkei Avot 1:10:8    Pesachim 70b:5
#
#   Conection Type                                             Text 1  \
# 0            NaN  A Jewish Critique of the Philosophy of Martin ...
# 1            NaN  A Jewish Critique of the Philosophy of Martin ...
# 2     commentary            A New Israeli Commentary on Pirkei Avot
# 3            NaN            A New Israeli Commentary on Pirkei Avot
# 4            NaN            A New Israeli Commentary on Pirkei Avot
#
#         Text 2      Category 1 Category 2  Link Count ref_1 heRef_1 path_1  \
# 0     Berakhot  Jewish Thought     Talmud         NaN   NaN     NaN    NaN
# 1      Shabbat  Jewish Thought     Talmud         NaN   NaN     NaN    NaN
# 2  Pirkei Avot         Mishnah    Mishnah         NaN   NaN     NaN    NaN
# 3    Sanhedrin         Mishnah     Talmud         NaN   NaN     NaN    NaN
# 4     Pesachim         Mishnah     Talmud         NaN   NaN     NaN    NaN
#
#    line_index_1             ref_2          heRef_2  \
# 0           NaN               NaN              NaN
# 1           NaN               NaN              NaN
# 2           NaN  Pirkei Avot 1:10  משנה אבות א, י,
# 3           NaN               NaN              NaN
# 4           NaN    Pesachim 70b:5     פסחים ע:, ה,
#
#                              path_2  line_index_2
# 0                               NaN           NaN
# 1                               NaN           NaN
# 2  אוצריא\משנה\סדר נזיקין\משנה אבות          12.0
# 3                               NaN           NaN
# 4  אוצריא\תלמוד\בבלי\סדר מועד\פסחים        2165.0

# %%
result_df = merged_df.dropna(subset=['path_1', 'path_2'])

# %%
result_df
# Out:
#                           Citation 1                      Citation 2  \
# 1041        Abarbanel on Amos 1:11:1                   Genesis 49:28
# 1042        Abarbanel on Amos 1:11:1                   Numbers 20:18
# 1043        Abarbanel on Amos 1:11:1                       Amos 1:11
# 1045        Abarbanel on Amos 1:13:1                   Proverbs 1:27
# 1046        Abarbanel on Amos 1:13:1                       Amos 1:13
# ...                              ...                             ...
# 3348126  Rashash on Bava Batra 28b:6   Tosafot on Bava Batra 28b:8:1
# 3348127  Rashash on Bava Batra 29a:2  Rashbam on Bava Batra 29a:11:1
# 3348128  Rashash on Bava Batra 29a:3  Tosafot on Bava Batra 29a:16:1
# 3348129  Rashash on Bava Batra 29a:4  Tosafot on Bava Batra 29a:18:1
# 3348130   Rashash on Bava Batra 2a:5    Tosafot on Bava Batra 2a:1:2
#
#         Conection Type                 Text 1                 Text 2  \
# 1041               NaN      Abarbanel on Amos                Genesis
# 1042               NaN      Abarbanel on Amos                Numbers
# 1043        commentary      Abarbanel on Amos                   Amos
# 1045               NaN      Abarbanel on Amos               Proverbs
# 1046        commentary      Abarbanel on Amos                   Amos
# ...                ...                    ...                    ...
# 3348126     commentary  Rashash on Bava Batra  Tosafot on Bava Batra
# 3348127     commentary  Rashash on Bava Batra  Rashbam on Bava Batra
# 3348128     commentary  Rashash on Bava Batra  Tosafot on Bava Batra
# 3348129     commentary  Rashash on Bava Batra  Tosafot on Bava Batra
# 3348130     commentary  Rashash on Bava Batra  Tosafot on Bava Batra
#
#         Category 1 Category 2  Link Count                        ref_1  \
# 1041        Tanakh     Tanakh         NaN     Abarbanel on Amos 1:11:1
# 1042        Tanakh     Tanakh         NaN     Abarbanel on Amos 1:11:1
# 1043        Tanakh     Tanakh         NaN     Abarbanel on Amos 1:11:1
# 1045        Tanakh     Tanakh         NaN     Abarbanel on Amos 1:13:1
# 1046        Tanakh     Tanakh         NaN     Abarbanel on Amos 1:13:1
# ...            ...        ...         ...                          ...
# 3348126     Talmud     Talmud         NaN  Rashash on Bava Batra 28b:6
# 3348127     Talmud     Talmud         NaN  Rashash on Bava Batra 29a:2
# 3348128     Talmud     Talmud         NaN  Rashash on Bava Batra 29a:3
# 3348129     Talmud     Talmud         NaN  Rashash on Bava Batra 29a:4
# 3348130     Talmud     Talmud         NaN   Rashash on Bava Batra 2a:5
#
#                            heRef_1  \
# 1041     אברבנאל על עמוס א, יא, א,
# 1042     אברבנאל על עמוס א, יא, א,
# 1043     אברבנאל על עמוס א, יא, א,
# 1045     אברבנאל על עמוס א, יג, א,
# 1046     אברבנאל על עמוס א, יג, א,
# ...                            ...
# 3348126   רש"ש על בבא בתרא כח:, ו,
# 3348127   רש"ש על בבא בתרא כט., ב,
# 3348128   רש"ש על בבא בתרא כט., ג,
# 3348129   רש"ש על בבא בתרא כט., ד,
# 3348130    רש"ש על בבא בתרא ב., ה,
#
#                                                     path_1  line_index_1  \
# 1041     אוצריא\תנך\ראשונים על התנ״ך\אברבנאל\נביאים\אבר...          30.0
# 1042     אוצריא\תנך\ראשונים על התנ״ך\אברבנאל\נביאים\אבר...          30.0
# 1043     אוצריא\תנך\ראשונים על התנ״ך\אברבנאל\נביאים\אבר...          30.0
# 1045     אוצריא\תנך\ראשונים על התנ״ך\אברבנאל\נביאים\אבר...          32.0
# 1046     אוצריא\תנך\ראשונים על התנ״ך\אברבנאל\נביאים\אבר...          32.0
# ...                                                    ...           ...
# 3348126  אוצריא\תלמוד\בבלי\אחרונים על התלמוד\רש״ש\סדר נ...         307.0
# 3348127  אוצריא\תלמוד\בבלי\אחרונים על התלמוד\רש״ש\סדר נ...         310.0
# 3348128  אוצריא\תלמוד\בבלי\אחרונים על התלמוד\רש״ש\סדר נ...         311.0
# 3348129  אוצריא\תלמוד\בבלי\אחרונים על התלמוד\רש״ש\סדר נ...         312.0
# 3348130  אוצריא\תלמוד\בבלי\אחרונים על התלמוד\רש״ש\סדר נ...           8.0
#
#                                   ref_2                         heRef_2  \
# 1041                      Genesis 49:28                  בראשית מט, כח,
# 1042                      Numbers 20:18                    במדבר כ, יח,
# 1043                          Amos 1:11                     עמוס א, יא,
# 1045                      Proverbs 1:27                     משלי א, כז,
# 1046                          Amos 1:13                     עמוס א, יג,
# ...                                 ...                             ...
# 3348126   Tosafot on Bava Batra 28b:8:1   תוספות על בבא בתרא כח:, ח, א,
# 3348127  Rashbam on Bava Batra 29a:11:1   רשב"ם על בבא בתרא כט., יא, א,
# 3348128  Tosafot on Bava Batra 29a:16:1  תוספות על בבא בתרא כט., טז, א,
# 3348129  Tosafot on Bava Batra 29a:18:1  תוספות על בבא בתרא כט., יח, א,
# 3348130    Tosafot on Bava Batra 2a:1:2    תוספות על בבא בתרא ב., א, ב,
#
#                                                     path_2  line_index_2
# 1041                                אוצריא\תנך\תורה\בראשית        1552.0
# 1042                                 אוצריא\תנך\תורה\במדבר         746.0
# 1043                                אוצריא\תנך\נביאים\עמוס          13.0
# 1045                                אוצריא\תנך\כתובים\משלי          29.0
# 1046                                אוצריא\תנך\נביאים\עמוס          15.0
# ...                                                    ...           ...
# 3348126  אוצריא\תלמוד\בבלי\ראשונים על התלמוד\תוספות\סדר...         673.0
# 3348127  אוצריא\תלמוד\בבלי\ראשונים על התלמוד\רשבם\סדר נ...          22.0
# 3348128  אוצריא\תלמוד\בבלי\ראשונים על התלמוד\תוספות\סדר...         682.0
# 3348129  אוצריא\תלמוד\בבלי\ראשונים על התלמוד\תוספות\סדר...         684.0
# 3348130  אוצריא\תלמוד\בבלי\ראשונים על התלמוד\תוספות\סדר...           6.0
#
# [2393730 rows x 16 columns]

# %%
result_df = result_df[['path_1','line_index_1','heRef_2','path_2', 'line_index_2','Conection Type']]

# %%
unique_paths = result_df['path_1'].unique()

for path in unique_paths:
    path_df = result_df[result_df['path_1'] == path]
    path_df.drop(['path_1'], axis=1, inplace=True)
    path = path.split('\\')[-1]
    path_df.to_json(f'../links/{path}_links.json', orient='records')
# Out:
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
# C:\Users\Goldman\AppData\Local\Temp\ipykernel_15604\726021565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path_df.drop(['path_1'], axis=1, inplace=True)
